# %%
# Import required libraries
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler, PowerTransformer, QuantileTransformer

# %%
# !pip install openpyxl

# %%
df = pd.read_excel('Titanic-Dataset.xlsx')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# Step 2: Perform Standardization on the variables: Age, Fare
df1=df.copy()
dfss=df1[['Age','Fare']]
dfss
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
sc=StandardScaler()
sc
# Out:
# StandardScaler()

# %%
dfss=sc.fit_transform(dfss)

# %%
dfss=pd.DataFrame(data=dfss,columns=['age','fare'])

# %%
dfss.describe()
# Out:
#                 age          fare
# count  7.140000e+02  8.910000e+02
# mean   2.388379e-16  3.987333e-18
# std    1.000701e+00  1.000562e+00
# min   -2.016979e+00 -6.484217e-01
# 25%   -6.595416e-01 -4.891482e-01
# 50%   -1.170488e-01 -3.573909e-01
# 75%    5.718310e-01 -2.424635e-02
# max    3.465126e+00  9.667167e+00

# %%
df1=pd.concat([df1,dfss],axis=1)
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.drop(['Age','Fare'],axis=1,inplace=True)
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
# Step 3: Perform feature scaling using Min-Max Scaler on the features: Pclass, Age, SibSp, Parch, Fare
df2=df.copy()

# %%
dfms= df2[['Pclass', 'Age', 'SibSp', 'Parch', 'Fare']]
ms= MinMaxScaler()
ms
# Out:
# MinMaxScaler()

# %%
dfms= ms.fit_transform(dfms)
dfms
# Out:
# array([[1.        , 0.27117366, 0.125     , 0.        , 0.01415106],
#        [0.        , 0.4722292 , 0.125     , 0.        , 0.13913574],
#        [1.        , 0.32143755, 0.        , 0.        , 0.01546857],
#        ...,
#        [1.        ,        nan, 0.125     , 0.33333333, 0.04577135],
#        [0.        , 0.32143755, 0.        , 0.        , 0.0585561 ],
#        [1.        , 0.39683338, 0.        , 0.        , 0.01512699]])

# %%
dfms= pd.DataFrame(dfms, columns=['pclass', 'age', 'sibSp', 'parch', 'fare'])
dfms
# Out:
#      pclass       age  sibSp     parch      fare
# 0       1.0  0.271174  0.125  0.000000  0.014151
# 1       0.0  0.472229  0.125  0.000000  0.139136
# 2       1.0  0.321438  0.000  0.000000  0.015469
# 3       0.0  0.434531  0.125  0.000000  0.103644
# 4       1.0  0.434531  0.000  0.000000  0.015713
# ..      ...       ...    ...       ...       ...
# 886     0.5  0.334004  0.000  0.000000  0.025374
# 887     0.0  0.233476  0.000  0.000000  0.058556
# 888     1.0       NaN  0.125  0.333333  0.045771
# 889     0.0  0.321438  0.000  0.000000  0.058556
# 890     1.0  0.396833  0.000  0.000000  0.015127
#
# [891 rows x 5 columns]

# %%
df2=pd.concat([df2,dfms],axis=1)

# %%
df2.drop(['Pclass', 'Age', 'SibSp', 'Parch', 'Fare'],axis=1,inplace=True)
df2
# Out:
#      PassengerId  Survived                                               Name  \
# 0              1         0                            Braund, Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         1                             Heikkinen, Miss. Laina
# 3              4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5         0                           Allen, Mr. William Henry
# ..           ...       ...                                                ...
# 886          887         0                              Montvila, Rev. Juozas
# 887          888         1                       Graham, Miss. Margaret Edith
# 888          889         0           Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1                              Behr, Mr. Karl Howell
# 890          891         0                                Dooley, Mr. Patrick
#
# ...

# %%
df2.describe()
# Out:
#        PassengerId    Survived      pclass         age       sibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    0.654321    0.367921    0.065376
# std     257.353842    0.486592    0.418036    0.182540    0.137843
# min       1.000000    0.000000    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    0.500000    0.247612    0.000000
# 50%     446.000000    0.000000    1.000000    0.346569    0.000000
# 75%     668.500000    1.000000    1.000000    0.472229    0.125000
# max     891.000000    1.000000    1.000000    1.000000    1.000000
#
#             parch        fare
# count  891.000000  891.000000
# mean     0.063599    0.062858
# std      0.134343    0.096995
# min      0.000000    0.000000
# 25%      0.000000    0.015440
# 50%      0.000000    0.028213
# 75%      0.000000    0.060508
# max      1.000000    1.000000

# %%
# Step 4: Perform feature scaling using Robust Scaler on the features: Pclass, Age, SibSp, Parch, Fare
df3=df.copy()

# %%
dfrs= df3[['Pclass', 'Age', 'SibSp', 'Parch', 'Fare']]
rs= RobustScaler()
rs
# Out:
# RobustScaler()

# %%
dfrs= rs.fit_transform(dfrs)
dfrs
# Out:
# array([[ 0.        , -0.33566434,  1.        ,  0.        , -0.3120106 ],
#        [-2.        ,  0.55944056,  1.        ,  0.        ,  2.46124229],
#        [ 0.        , -0.11188811,  0.        ,  0.        , -0.28277666],
#        ...,
#        [ 0.        ,         nan,  1.        ,  2.        ,  0.38960398],
#        [-2.        , -0.11188811,  0.        ,  0.        ,  0.67328148],
#        [ 0.        ,  0.22377622,  0.        ,  0.        , -0.29035583]])

# %%
dfrs= pd.DataFrame(dfrs, columns=['pclass', 'age', 'sibSp', 'parch', 'fare'])
dfrs
# Out:
#      pclass       age  sibSp  parch      fare
# 0       0.0 -0.335664    1.0    0.0 -0.312011
# 1      -2.0  0.559441    1.0    0.0  2.461242
# 2       0.0 -0.111888    0.0    0.0 -0.282777
# 3      -2.0  0.391608    1.0    0.0  1.673732
# 4       0.0  0.391608    0.0    0.0 -0.277363
# ..      ...       ...    ...    ...       ...
# 886    -1.0 -0.055944    0.0    0.0 -0.062981
# 887    -2.0 -0.503497    0.0    0.0  0.673281
# 888     0.0       NaN    1.0    2.0  0.389604
# 889    -2.0 -0.111888    0.0    0.0  0.673281
# 890     0.0  0.223776    0.0    0.0 -0.290356
#
# [891 rows x 5 columns]

# %%
df3=pd.concat([df3,dfrs],axis=1)

# %%
df3.drop(['Pclass', 'Age', 'SibSp', 'Parch', 'Fare'],axis=1,inplace=True)
df3
# Out:
#      PassengerId  Survived                                               Name  \
# 0              1         0                            Braund, Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         1                             Heikkinen, Miss. Laina
# 3              4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5         0                           Allen, Mr. William Henry
# ..           ...       ...                                                ...
# 886          887         0                              Montvila, Rev. Juozas
# 887          888         1                       Graham, Miss. Margaret Edith
# 888          889         0           Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1                              Behr, Mr. Karl Howell
# 890          891         0                                Dooley, Mr. Patrick
#
# ...

# %%
df3.describe()
# Out:
#        PassengerId    Survived      pclass         age       sibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838   -0.691358    0.095056    0.523008
# std     257.353842    0.486592    0.836071    0.812671    1.102743
# min       1.000000    0.000000   -2.000000   -1.542937    0.000000
# 25%     223.500000    0.000000   -1.000000   -0.440559    0.000000
# 50%     446.000000    0.000000    0.000000    0.000000    0.000000
# 75%     668.500000    1.000000    0.000000    0.559441    1.000000
# max     891.000000    1.000000    0.000000    2.909091    8.000000
#
#             parch        fare
# count  891.000000  891.000000
# mean     0.381594    0.768745
# std      0.806057    2.152200
# min      0.000000   -0.626005
# 25%      0.000000   -0.283409
# 50%      0.000000    0.000000
# 75%      0.000000    0.716591
# max      6.000000   21.562738

# %%
# Step 5: Perform feature scaling using Power Transformer Scaler on the features: Pclass, Age, SibSp, Parch, Fare
df4=df.copy()

# %%
dfpt= df4[['Pclass', 'Age', 'SibSp', 'Parch', 'Fare']]
pt=PowerTransformer()
pt
# Out:
# PowerTransformer()

# %%
dfpt= pt.fit_transform(dfpt)
dfpt
# Out:
# array([[ 0.86397329, -0.47217157,  1.37363642, -0.56025296, -0.87882001],
#        [-1.45912855,  0.60501686,  1.37363642, -0.56025296,  1.33665056],
#        [ 0.86397329, -0.18937637, -0.67984996, -0.56025296, -0.79006485],
#        ...,
#        [ 0.86397329,         nan,  1.37363642,  1.84685634,  0.28888536],
#        [-1.45912855, -0.18937637, -0.67984996, -0.56025296,  0.52790578],
#        [ 0.86397329,  0.21660162, -0.67984996, -0.56025296, -0.81234947]])

# %%
dfpt= pd.DataFrame(dfpt, columns=['pclass', 'age', 'sibSp', 'parch', 'fare'])
dfpt
# Out:
#        pclass       age     sibSp     parch      fare
# 0    0.863973 -0.472172  1.373636 -0.560253 -0.878820
# 1   -1.459129  0.605017  1.373636 -0.560253  1.336651
# 2    0.863973 -0.189376 -0.679850 -0.560253 -0.790065
# 3   -1.459129  0.412768  1.373636 -0.560253  1.067352
# 4    0.863973  0.412768 -0.679850 -0.560253 -0.774439
# ..        ...       ...       ...       ...       ...
# 886 -0.592604 -0.120309 -0.679850 -0.560253 -0.294907
# 887 -1.459129 -0.692126 -0.679850 -0.560253  0.527906
# 888  0.863973       NaN  1.373636  1.846856  0.288885
# 889 -1.459129 -0.189376 -0.679850 -0.560253  0.527906
# 890  0.863973  0.216602 -0.679850 -0.560253 -0.812349
#
# [891 rows x 5 columns]

# %%
df4=pd.concat([df4,dfpt],axis=1)

# %%
df4.drop(['Pclass', 'Age', 'SibSp', 'Parch', 'Fare'],axis=1,inplace=True)
df4
# Out:
#      PassengerId  Survived                                               Name  \
# 0              1         0                            Braund, Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         1                             Heikkinen, Miss. Laina
# 3              4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5         0                           Allen, Mr. William Henry
# ..           ...       ...                                                ...
# 886          887         0                              Montvila, Rev. Juozas
# 887          888         1                       Graham, Miss. Margaret Edith
# 888          889         0           Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1                              Behr, Mr. Karl Howell
# 890          891         0                                Dooley, Mr. Patrick
#
# ...

# %%
df4.describe()
# Out:
#        PassengerId    Survived        pclass           age         sibSp  \
# count   891.000000  891.000000  8.910000e+02  7.140000e+02  8.910000e+02
# mean    446.000000    0.383838 -1.036707e-16 -4.975789e-18  9.170866e-17
# std     257.353842    0.486592  1.000562e+00  1.000701e+00  1.000562e+00
# min       1.000000    0.000000 -1.459129e+00 -2.394799e+00 -6.798500e-01
# 25%     223.500000    0.000000 -5.926039e-01 -6.087862e-01 -6.798500e-01
# 50%     446.000000    0.000000  8.639733e-01 -5.183492e-02 -6.798500e-01
# 75%     668.500000    1.000000  8.639733e-01  6.050169e-01  1.373636e+00
# max     891.000000    1.000000  8.639733e-01  3.022690e+00  1.780003e+00
#
#               parch          fare
# count  8.910000e+02  8.910000e+02
# mean   1.295883e-17  3.439075e-16
# std    1.000562e+00  1.000562e+00
# min   -5.602530e-01 -3.534079e+00
# 25%   -5.602530e-01 -7.919073e-01
# 50%   -5.602530e-01 -1.891020e-01
# 75%   -5.602530e-01  5.594584e-01
# ...

# %%
# Step 6: Perform feature scaling using Quantile Transformer Scaler on the features: Pclass, Age, SibSp, Parch, Fare
df5=df.copy()

# %%
dfqt= df5[['Pclass', 'Age', 'SibSp', 'Parch', 'Fare']]
qt=QuantileTransformer()
qt
# Out:
# QuantileTransformer()

# %%
dfqt= qt.fit_transform(dfqt)
dfqt
# Out:
# /opt/anaconda3/envs/new_env/lib/python3.10/site-packages/sklearn/preprocessing/_data.py:2785: UserWarning: n_quantiles (1000) is greater than the total number of samples (891). n_quantiles is set to n_samples.
#   warnings.warn(
# array([[1.        , 0.30449438, 0.8005618 , 0.        , 0.08483146],
#        [0.        , 0.74494382, 0.8005618 , 0.        , 0.88539326],
#        [1.        , 0.43370787, 0.        , 0.        , 0.25955056],
#        ...,
#        [1.        ,        nan, 0.8005618 , 0.93820225, 0.61235955],
#        [0.        , 0.43370787, 0.        , 0.        , 0.73370787],
#        [1.        , 0.61235955, 0.        , 0.        , 0.13764045]])

# %%
dfqt= pd.DataFrame(dfqt, columns=['pclass', 'age', 'sibSp', 'parch', 'fare'])
dfqt
# Out:
#        pclass       age     sibSp     parch      fare
# 0    1.000000  0.304494  0.800562  0.000000  0.084831
# 1    0.000000  0.744944  0.800562  0.000000  0.885393
# 2    1.000000  0.433708  0.000000  0.000000  0.259551
# 3    0.000000  0.683708  0.800562  0.000000  0.838764
# 4    1.000000  0.683708  0.000000  0.000000  0.295506
# ..        ...       ...       ...       ...       ...
# 886  0.344944  0.459551  0.000000  0.000000  0.456180
# 887  0.000000  0.211798  0.000000  0.000000  0.733708
# 888  1.000000       NaN  0.800562  0.938202  0.612360
# 889  0.000000  0.433708  0.000000  0.000000  0.733708
# 890  1.000000  0.612360  0.000000  0.000000  0.137640
#
# [891 rows x 5 columns]

# %%
df5=pd.concat([df5,dfqt],axis=1)

# %%
df5.drop(['Pclass', 'Age', 'SibSp', 'Parch', 'Fare'],axis=1,inplace=True)
df5
# Out:
#      PassengerId  Survived                                               Name  \
# 0              1         0                            Braund, Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         1                             Heikkinen, Miss. Laina
# 3              4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5         0                           Allen, Mr. William Henry
# ..           ...       ...                                                ...
# 886          887         0                              Montvila, Rev. Juozas
# 887          888         1                       Graham, Miss. Margaret Edith
# 888          889         0           Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1                              Behr, Mr. Karl Howell
# 890          891         0                                Dooley, Mr. Patrick
#
# ...

# %%
df5.describe()
# Out:
#        PassengerId    Survived      pclass         age       sibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    0.622300    0.500034    0.267435
# std     257.353842    0.486592    0.434272    0.289189    0.394230
# min       1.000000    0.000000    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    0.344944    0.242679    0.000000
# 50%     446.000000    0.000000    1.000000    0.489326    0.000000
# 75%     668.500000    1.000000    1.000000    0.744944    0.800562
# max     891.000000    1.000000    1.000000    1.000000    1.000000
#
#             parch        fare
# count  891.000000  891.000000
# mean     0.210457    0.499631
# std      0.376874    0.289266
# min      0.000000    0.000000
# 25%      0.000000    0.243820
# 50%      0.000000    0.497753
# 75%      0.000000    0.748876
# max      1.000000    1.000000

# %%
# Concatenate all scaled dataframes with the original df
df = pd.concat([dfss, dfrs, dfms, dfpt, dfqt], axis=1)

# %%
df
# Out:
#           age      fare  pclass       age  sibSp  parch      fare  pclass  \
# 0   -0.530377 -0.502445     0.0 -0.335664    1.0    0.0 -0.312011     1.0
# 1    0.571831  0.786845    -2.0  0.559441    1.0    0.0  2.461242     0.0
# 2   -0.254825 -0.488854     0.0 -0.111888    0.0    0.0 -0.282777     1.0
# 3    0.365167  0.420730    -2.0  0.391608    1.0    0.0  1.673732     0.0
# 4    0.365167 -0.486337     0.0  0.391608    0.0    0.0 -0.277363     1.0
# ..        ...       ...     ...       ...    ...    ...       ...     ...
# 886 -0.185937 -0.386671    -1.0 -0.055944    0.0    0.0 -0.062981     0.5
# 887 -0.737041 -0.044381    -2.0 -0.503497    0.0    0.0  0.673281     0.0
# 888       NaN -0.176263     0.0       NaN    1.0    2.0  0.389604     1.0
# 889 -0.254825 -0.044381    -2.0 -0.111888    0.0    0.0  0.673281     0.0
# 890  0.158503 -0.492378     0.0  0.223776    0.0    0.0 -0.290356     1.0
#
#           age  sibSp  ...    pclass       age     sibSp     parch      fare  \
# ...
